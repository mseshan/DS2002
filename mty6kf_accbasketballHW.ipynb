# %% [markdown]
# NOTE: Reflection is at the end of this assignment

# %%
#1. READING THE CSV FILE:
import pandas as pd

acc_players_df = pd.read_csv ('/content/drive/MyDrive/Fall 24/Colab Notebooks DS 2002/acc_players-2324F edited.csv')

print("First 5 rows of the DataFrame:")
display(acc_players_df.head())
# Out:
# First 5 rows of the DataFrame:
#    Rk         Player Class Pos          School   G   MP  TRB  AST  STL  ...  \
# 0   1   Amaree Abram    SO   G    Georgia Tech  10  108   17   11    1  ...
# 1   2   Sola Adebisi    FR   F   Florida State   7    9    1    1    0  ...
# 2   3  Prince Aligbe    SO   F  Boston College  35  651  119   21   15  ...
# 3   4     Abe Atiyeh    SR   G  Boston College   4    6    0    0    0  ...
# 4   5    Zack Austin    JR   F      Pittsburgh  33  746  137   29   32  ...
#
#    TOV  PF  PTS    FG%    2P%    3P%    FT%   PER   WS  BPM
# 0    9  10   34  0.262  0.318  0.200  0.615   4.1 -0.1 -6.4
# 1    1   1    2  0.500  0.500    NaN    NaN   3.5  0.0 -6.7
# 2   30  51  164  0.435  0.522  0.147  0.620   9.4  0.9 -1.3
# 3    1   0    3  0.333  0.000  1.000    NaN   1.1  0.0 -8.2
# 4   13  35  216  0.417  0.563  0.295  0.737  18.0  2.9  7.9
#
# [5 rows x 21 columns]

# %%
print(acc_players_df.columns)
# Out:
# Index(['Rk', 'Player', 'Class', 'Pos', 'School', 'G', 'MP', 'TRB', 'AST',
#        'STL', 'BLK', 'TOV', 'PF', 'PTS', 'FG%', '2P%', '3P%', 'FT%', 'PER',
#        'WS', 'BPM'],
#       dtype='object')

# %%
#2. BASIC ANALYSIS

#calculate the total points scored by all players combined:
totalpoints = acc_players_df['PTS'].sum()
print("Total Points scored by all players:", totalpoints)

#find the player who has played the most minutes (MP):
most_minutes_player = acc_players_df.groupby('Player')['MP'].sum().idxmax()
print("Player who has played the most minutes:", most_minutes_player)

#identify the top 5 players in terms of total rebounds (TRB):
top_5_rebounds = acc_players_df.groupby('Player')['TRB'].sum().nlargest(5)
print("Top 5 players in terms of total rebounds:", top_5_rebounds)
# Out:
# Total Points scored by all players: 38411
# Player who has played the most minutes: Casey Morsell
# Top 5 players in terms of total rebounds: Player
# Armando Bacot      380
# Ian Schieffelin    340
# Harrison Ingram    327
# Mohamed Diarra     311
# Norchad Omier      309
# Name: TRB, dtype: int64

# %%
#3. PLAYER FILTERING

#Create a new DataFrame containing only players who played more than 500 minutes
players_above_500mins = acc_players_df[acc_players_df['MP'] > 500]
print("Players who played more than 500 minutes:")
display(players_above_500mins)


#From this filtered DataFrame, determine the player with the highest total assists (AST).
highest_assists_player = players_above_500mins.groupby('Player')['AST'].sum().idxmax()
print("Player with the highest total assists:", highest_assists_player)

#Who are the top 3 Assist Leads in the League?
top_3_assist_leads = acc_players_df.groupby('Player')['AST'].sum().nlargest(3)
print("Top 3 Assist Leads in the League:")
display(top_3_assist_leads)

#Who are the top 3 Shot Blockers?
top_3_shot_blockers = acc_players_df.groupby('Player')['BLK'].sum().nlargest(3)
print("Top 3 Shot Blockers:")
display(top_3_shot_blockers)
# Out:
# Players who played more than 500 minutes:
#       Rk            Player Class Pos          School   G    MP  TRB  AST  STL  \
# 2      3     Prince Aligbe    SO   F  Boston College  35   651  119   21   15
# 4      5       Zack Austin    JR   F      Pittsburgh  33   746  137   29   32
# 5      6     Armando Bacot    SR   F  North Carolina  37  1123  380   56   22
# 7      8     Reece Beekman    SR   G        Virginia  34  1114  124  212   68
# 9     10        Chris Bell    SO   F        Syracuse  32   865   75   21   18
# ..   ...               ...   ...  ..             ...  ..   ...  ...  ...  ...
# 203  204     Jamir Watkins    JR   F   Florida State  33   928  199   91   64
# 206  207         Tre White    SO   G      Louisville  29   907  170   39   24
# 207  208  Chauncey Wiggins    SO   F         Clemson  36   639   76   33    6
# 209  210   Curtis Williams    FR   G      Louisville  32   564   42   20   12
# ...

# %%
#4. SCHOOL-BASED ANALYSIS

#Group the players by School and calculate the total points scored by each school.
school_points = acc_players_df.groupby('School')['PTS'].sum()
print("Total Points scored by each school:", school_points)

#Group the players by School and calculate the total assists (AST) for each team.
school_assists = acc_players_df.groupby('School')['AST'].sum()
print("Total Assists by each school:", school_assists)

#Sort the schools by total points scored and display the top 3 schools.
top_3_schools_by_points = school_points.nlargest(3)
print("Top 3 Schools by Total Points Scored:")
display(top_3_schools_by_points)
# Out:
# Total Points scored by each school: School
# Boston College    2667
# Clemson           2785
# Duke              2830
# Florida State     2526
# Georgia Tech      2272
# Louisville        2304
# Miami (FL)        2424
# NC State          3101
# North Carolina    3032
# Notre Dame        2113
# Pittsburgh        2495
# Syracuse          2442
# Virginia          2140
# Virginia Tech     2547
# Wake Forest       2733
# Name: PTS, dtype: int64
# Total Assists by each school: School
# Boston College    509
# Clemson           533
# Duke              551
# Florida State     406
# Georgia Tech      425
# Louisville        356
# Miami (FL)        454
# NC State          536
# North Carolina    536
# Notre Dame        335
# Pittsburgh        452
# Syracuse          442
# Virginia          509
# Virginia Tech     514
# Wake Forest       429
# Name: AST, dtype: int64
# Top 3 Schools by Total Points Scored:
# School
# NC State          3101
# North Carolina    3032
# Duke              2830
# ...

# %%
#5. EXTRA CREDIT (BONUS)

#Create a bar chart showing the top 5 players by total points scored (PTS).
top_5_players_by_points = acc_players_df.groupby('Player')['PTS'].sum().nlargest(5)
top_5_players_by_points.plot(kind='bar', title='Top 5 Players by Total Points Scored')
# Out:
# Correlation between FG% and WS: 0.4210663894199787

# %%
#Correlation (bonus)
import matplotlib.pyplot as plt

plt.scatter(acc_players_df['FG%'], acc_players_df['WS'])
plt.xlabel('Field Goal Percentage')
plt.ylabel('Win Shares')
plt.title('Field Goal Percentage vs. Win Shares')

correlation = acc_players_df['FG%'].corr(acc_players_df['WS'])
print("Correlation between FG% and WS:", correlation)
# Out:
# Correlation between FG% and WS: 0.4210663894199787

# %% [markdown]
# REFLECTION:
#
#
# Working with CSV files and pandas DataFrames has shown me that many of the coding techniques I employed followed a similar pattern. I feel significantly more comfortable with various DataFrame methods, such as .head(), .groupby(), and locating maximum values within a dataset. Compared to my first homework assignment, I navigated this one with greater ease and faced fewer complications. My troubleshooting skills have also improved, allowing me to address issues more effectively. One of my favorite aspects of these assignments is creating graphs. Visualizing data makes it much more appealing and understandable, and I found it surprisingly straightforward to generate these visuals. This skill is particularly important when working with larger datasets, as visual representations can simplify complex information. Although this assignment didn’t require an in-depth analysis of the data, it provided valuable practice, and I can see myself becoming increasingly comfortable with these techniques as we continue.
#
#
# One of the initial challenges I faced involved the names of the columns in the spreadsheet. When I attempted to perform the basic analysis, I encountered errors indicating that none of the column names existed. To resolve this, I used print(acc_players_df.columns) to display the column names. I discovered that it was only reading categories such as 'Totals,' 'Shooting,' and 'Advanced.' Although I eventually overcame this issue, it delayed my progress at the beginning of the assignment. Additionally, I had to familiarize myself with identifying the top players in the dataset using the idxmax() function. After using it multiple times throughout the assignment, I now feel much more confident in my ability to apply it.
#
#
# In terms of broader implications, the insights gained from analyzing basketball statistics can be applied to various fields, including business analysis and social sciences. For instance, similar analytical techniques can be employed to assess customer engagement, market trends, and sales performance in a business context. In research, the ability to identify trends and patterns can enhance the understanding of social phenomena, leading to more informed conclusions and decisions. Overall, this assignment allowed me to practice more CSV files and DataFrames by using different tools.
